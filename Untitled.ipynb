# %%
import pandas as pd
import ipywidgets as widgets
from ipywidgets import VBox, HTML
from IPython.display import display, clear_output, HTML as dispHTML

# Datos: asignaciones y mapeo de nombres
assignments = [
    {"Semana": "1", "Obra": "Teatro breve para gente brava", "Tipo": "Repertorio", "Día": "Viernes", "Fecha": "28/03/2025", "Función": "Función 1", "Equipo": ["JS", "J", "N", "NC"]},
    {"Semana": "1", "Obra": "Teatro breve para gente brava", "Tipo": "Repertorio", "Día": "Sábado", "Fecha": "29/03/2025", "Función": "Función 2", "Equipo": ["K", "L", "S", "NC"]},
    {"Semana": "2", "Obra": "Proyecto Piloto", "Tipo": "Repertorio", "Día": "Viernes", "Fecha": "04/04/2025", "Función": "Función 3", "Equipo": ["JS", "K", "M", "N"]},
    {"Semana": "2", "Obra": "Proyecto Piloto", "Tipo": "Repertorio", "Día": "Sábado", "Fecha": "05/04/2025", "Función": "Función 4", "Equipo": ["K", "M", "S", "NC"]},
    {"Semana": "3", "Obra": "El círculo del centauro", "Tipo": "Repertorio", "Día": "Viernes", "Fecha": "11/04/2025", "Función": "Función 5", "Equipo": ["JS", "J", "L", "N"]},
    {"Semana": "3", "Obra": "El círculo del centauro", "Tipo": "Repertorio", "Día": "Sábado", "Fecha": "12/04/2025", "Función": "Función 6", "Equipo": ["JS", "M", "S", "NC"]},
    {"Semana": "4", "Obra": "Jesús", "Tipo": "Repertorio", "Día": "Viernes", "Fecha": "25/04/2025", "Función": "Función 7", "Equipo": ["JS", "J", "L", "N"]},
    {"Semana": "4", "Obra": "Jesús", "Tipo": "Repertorio", "Día": "Sábado", "Fecha": "26/04/2025", "Función": "Función 8", "Equipo": ["K", "M", "S", "NC"]},
    {"Semana": "5", "Obra": "Tríptico místico Polaroid, El aracano del Mago", "Tipo": "Repertorio", "Día": "Viernes", "Fecha": "02/05/2025", "Función": "Función 9", "Equipo": ["JS", "J", "K", "N"]},
    {"Semana": "5", "Obra": "Tríptico místico Polaroid, El aracano del Mago", "Tipo": "Repertorio", "Día": "Sábado", "Fecha": "03/05/2025", "Función": "Función 10", "Equipo": ["L", "M", "S", "NC"]},
    {"Semana": "6", "Obra": "El cerezo Volador", "Tipo": "Estreno", "Día": "Jueves", "Fecha": "08/05/2025", "Función": "Función 11", "Equipo": ["JS", "J", "L", "N"]},
    {"Semana": "6", "Obra": "El cerezo Volador", "Tipo": "Estreno", "Día": "Viernes", "Fecha": "09/05/2025", "Función": "Función 12", "Equipo": ["K", "M", "N", "S"]},
    {"Semana": "6", "Obra": "El cerezo Volador", "Tipo": "Estreno", "Día": "Sábado", "Fecha": "10/05/2025", "Función": "Función 13", "Equipo": ["J", "L", "S", "NC"]},
    {"Semana": "7", "Obra": "Percloruro de Hierro", "Tipo": "Estreno", "Día": "Jueves", "Fecha": "15/05/2025", "Función": "Función 14", "Equipo": ["JS", "J", "L", "N"]},
    {"Semana": "7", "Obra": "Percloruro de Hierro", "Tipo": "Estreno", "Día": "Viernes", "Fecha": "16/05/2025", "Función": "Función 15", "Equipo": ["K", "J", "S", "NC"]},
    {"Semana": "7", "Obra": "Percloruro de Hierro", "Tipo": "Estreno", "Día": "Sábado", "Fecha": "17/05/2025", "Función": "Función 16", "Equipo": ["JS", "K", "L", "NC"]},
    {"Semana": "8", "Obra": "Semestre IX", "Tipo": "Estreno", "Día": "Jueves", "Fecha": "22/05/2025", "Función": "Función 17", "Equipo": ["J", "M", "N", "NC"]},
    {"Semana": "8", "Obra": "Semestre IX", "Tipo": "Estreno", "Día": "Viernes", "Fecha": "23/05/2025", "Función": "Función 18", "Equipo": ["K", "M", "S", "L"]},
    {"Semana": "8", "Obra": "Semestre IX", "Tipo": "Estreno", "Día": "Sábado", "Fecha": "24/05/2025", "Función": "Función 19", "Equipo": ["JS", "M", "S", "L"]}
]

name_mapping = {
    "Juan Sebastián Correa Ceballos": "JS",
    "Juliana Andréa Chacón": "J",
    "Karen Dayana Cuéllar": "K",
    "Laura Marcela Taborda": "L",
    "Miguel Ángel Hernández Silva": "M",
    "Natalia Correa López": "N",
    "Saray Jaramillo Domínguez": "S",
    "Nicolás Cadena": "NC"
}

# Convertir la lista de asignaciones en un DataFrame
df_assignments = pd.DataFrame(assignments)

# Lista de opciones con un placeholder
options = [("Seleccione un colaborador", "")] + [(f"{abbr}: {full}", abbr) for full, abbr in name_mapping.items()]

# Widget de salida para mostrar la tabla y el instructivo
output = widgets.Output()

# Instructivo y consideraciones (texto formateado en HTML)
instructions_text = """
<h3>INSTRUCTIVO Y CONSIDERACIONES PARA EL PERSONAL DE APOYO LOGÍSTICO</h3>
<h4>HORARIO Y TURNOS</h4>
<ul>
  <li><b>Hora de llegada:</b> Todo el equipo debe llegar puntualmente a las 4:00 pm para iniciar la preparación.</li>
  <li><b>Duración del turno:</b>
    <ul>
      <li>General: Cada función es un turno de 5 horas (de 4:00 pm a 9:00 pm).</li>
      <li>Excepción para Nicolás Cadena: Deberá retirarse a las 8:00 pm, trabajando 4 horas por turno.</li>
    </ul>
  </li>
</ul>
<h4>DISTRIBUCIÓN DE FUNCIONES</h4>
<ul>
  <li>Repertorios: Se presentan 10 funciones en 5 semanas (viernes y sábado).</li>
  <li>Estrenos: Se presentan 9 funciones en 3 semanas (jueves, viernes y sábado).</li>
</ul>
<p>Se han distribuido 63 asignaciones entre los colaboradores principales para que cada uno cumpla 9 turnos (45 horas en total), excepto Nicolás, que tendrá 10 turnos de 4 horas (40 horas).</p>

<h4>FUNCIONES DEL PERSONAL DE APOYO LOGÍSTICO EN SALA DE TEATRO</h4>
<p><b>Antes de la función:</b></p>
<ul>
  <li>Llegar a las 4:00 pm y colaborar en el montaje de la sala, organización de equipos técnicos, verificación de accesos y control de seguridad.</li>
  <li>Informar al público que espera fuera de la sala, ordenarlo y entregar las boletas gratuitas hasta completar el aforo de 120 personas.</li>
</ul>
<p><b>Durante la función:</b></p>
<ul>
  <li>Controlar el ingreso guiado: en la puerta, recibir y revisar las boletas para evitar sobrecupos.</li>
  <li>Una persona del equipo debe estar al interior de la sala para agilizar la acomodación del público.</li>
  <li>Supervisar el orden y la seguridad tanto dentro como fuera de la sala.</li>
  <li>Asistir en la coordinación de cambios de escena y en la solución de imprevistos técnicos o logísticos.</li>
  <li>Mantener comunicación constante con la coordinación del evento y el director docente encargado.</li>
</ul>
<p><b>Después de la función:</b></p>
<ul>
  <li>Participar en el desmontaje y la reorganización del espacio.</li>
  <li>Recoger y reportar incidencias, y asistir en el cierre administrativo de la sala.</li>
</ul>
"""

def update_output(selected_code):
    with output:
        clear_output()
        if selected_code == "":
            print("Por favor, seleccione un colaborador.")
        else:
            # Filtrar asignaciones según el código seleccionado
            filtered = df_assignments[df_assignments["Equipo"].apply(lambda team: selected_code in team)]
            full_name = [name for name, code in name_mapping.items() if code == selected_code][0]
            if filtered.empty:
                print(f"No se encontraron asignaciones para {selected_code}.")
            else:
                print(f"Asignaciones para {selected_code} ({full_name}):")
                display(filtered)
            # Mostrar el instructivo completo
            print("\n")
            display(dispHTML(instructions_text))

def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        update_output(change['new'])

# Crear el widget Dropdown
dropdown = widgets.Dropdown(
    options=options,
    description="Colaborador:",
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='50%')
)
dropdown.observe(on_change, names='value')

# Encabezado con las convenciones de nombres
header = HTML("""
<h3>Convenciones de Nombres</h3>
<ul>
  <li><b>JS</b>: Juan Sebastián Correa Ceballos</li>
  <li><b>J</b>: Juliana Andréa Chacón</li>
  <li><b>K</b>: Karen Dayana Cuéllar</li>
  <li><b>L</b>: Laura Marcela Taborda</li>
  <li><b>M</b>: Miguel Ángel Hernández Silva</li>
  <li><b>N</b>: Natalia Correa López</li>
  <li><b>S</b>: Saray Jaramillo Domínguez</li>
  <li><b>NC</b>: Nicolás Cadena</li>
</ul>
<p>Seleccione su colaborador en el menú desplegable para ver sus asignaciones y la información importante.</p>
""")
            

# Organizar la interfaz en una sola caja (encabezado, dropdown y salida)
ui = VBox([header, dropdown, output])
display(ui)
